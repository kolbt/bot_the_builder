# %% [markdown]
# # Computing product ease of assembly with NLP

# %%
# Import cell
import numpy as np
import pandas as pd
import string
import re
import nltk
from nltk.stem import WordNetLemmatizer 
#importing plotly and cufflinks in offline mode
import cufflinks as cf
import plotly.offline
import gensim
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.manifold import TSNE
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Products that I've scraped data for
product_set = ( 'office+chair',
                'office+desk',
                'kitchen+table',
                'living+room+couch',
                'end+table',
                'bed+frame',
                'crib',
                'bookcase',
                'coffee+table')

# %%
# Load in your csv data
product_dfs = []
for i in product_set:
    this_df = pd.read_csv('./review_csvs/' + i + '_review_data.csv')
    this_df.insert(0, 'Type', i)
    product_dfs.append(this_df)
products = pd.concat(product_dfs)

# Add a column for product ID
product_list = []
product_review_count = []
product_id = -1
id_list = []
for i in range(len(products['product'])):
    # If the product isn't yet in the list...
    if products['product'].iloc[i] not in product_list:
        # Add it to the list of distinct products
        product_list.append(products['product'].iloc[i])
        # Add new counter for number of reviews
        product_review_count.append(1)
        # Increment the distinct product id number
        product_id += 1
        
    id_list.append(product_id)
    product_review_count[-1] += 1
    
# Add the product id to the dataframe
products.insert(0, 'id', id_list)

# Print the id and name of the product with the most reviews
most_reviews = max(product_review_count)
most_reviews_id = product_review_count.index(most_reviews)
most_reviews_name = product_list[most_reviews_id]
print(f'{most_reviews_name} has the most product reviews: {most_reviews}')

display(products)
# Out:
# GTRACING Gaming Chair Racing Office Computer Game Chair Ergonomic Backrest and Seat Height Adjustment Recliner Swivel Rocker with Headrest and Lumbar Pillow E-Sports Chair Red has the most product reviews: 1001
#       id          Type                                      title  \
# 0      0  office+chair  Good if you only need a chair for a month
# 1      0  office+chair                                Unfortunate
# 2      0  office+chair                   Wrong parts and unusable
# 3      0  office+chair             the chair back rest was hollow
# 4      0  office+chair           Great Office Chair for the money
# ..   ...           ...                                        ...
# 800  444  coffee+table                  I am over the moon happy!
# 801  444  coffee+table              Beyond any expectations I had
# 802  444  coffee+table                  Great Ottoman, Good Price
# 803  444  coffee+table           Practically perfect in every way
# 804  444  coffee+table         Cushion is comfy like memory foam!
#
#                                                content         date  \
# 0    The fabric/pleather on this chair has torn aft...  13 May 2020
# 1    Received chair and all of the parts for assemb...  05 Apr 2020
# 2                   Came with incorrect mount for seat  21 Mar 2020
# 3    the back rest was hollow, when i received the ...  10 Aug 2020
# 4    After reading all of the reviews I decided to ...  26 Mar 2020
# ..                                                 ...          ...
# 800  There is absolutely everything right about thi...  03 Aug 2019
# 801  This is a beautiful piece of furniture. It can...  26 Aug 2018
# 802  This ottoman really does the job in my living ...  02 Oct 2017
# 803  Gorgeous piece that feels so custom because it...  12 Jan 2019
# 804  This is a great item. Easy to assemble- just t...  13 May 2020
#
#           variant                                             images verified  \
# 0    Color: Black  https://images-na.ssl-images-amazon.com/images...      Yes
# 1    Color: Black                                                NaN      Yes
# 2    Color: Black  https://images-na.ssl-images-amazon.com/images...      Yes
# 3    Color: Black                                                NaN      Yes
# 4    Color: Black                                                NaN      Yes
# ..            ...                                                ...      ...
# 800           NaN  https://images-na.ssl-images-amazon.com/images...      Yes
# 801           NaN  https://images-na.ssl-images-amazon.com/images...      Yes
# 802           NaN                                                NaN      Yes
# 803           NaN  https://images-na.ssl-images-amazon.com/images...      Yes
# 804           NaN                                                NaN      Yes
#
#            author  rating                                            product  \
# 0             Idk     1.0  AmazonBasics Classic Puresoft PU-Padded Mid-Ba...
# 1           Jen P     2.0  AmazonBasics Classic Puresoft PU-Padded Mid-Ba...
# 2         Smelvin     1.0  AmazonBasics Classic Puresoft PU-Padded Mid-Ba...
# 3    daniel lomas     1.0  AmazonBasics Classic Puresoft PU-Padded Mid-Ba...
# 4       AzIronman     5.0  AmazonBasics Classic Puresoft PU-Padded Mid-Ba...
# ..            ...     ...                                                ...
# 800      cynthiab     5.0  30 Inch Distressed Vegan Leather, Tufted Coffe...
# 801    Shannon S.     5.0  30 Inch Distressed Vegan Leather, Tufted Coffe...
# 802         Sarah     4.0  30 Inch Distressed Vegan Leather, Tufted Coffe...
# 803        Nicole     5.0  30 Inch Distressed Vegan Leather, Tufted Coffe...
# 804       Rdy2Run     5.0  30 Inch Distressed Vegan Leather, Tufted Coffe...
#
#                                                    url
# 0    /AmazonBasics-Puresoft-PU-Padded-Mid-Back-Comp...
# 1    /AmazonBasics-Puresoft-PU-Padded-Mid-Back-Comp...
# 2    /AmazonBasics-Puresoft-PU-Padded-Mid-Back-Comp...
# 3    /AmazonBasics-Puresoft-PU-Padded-Mid-Back-Comp...
# 4    /AmazonBasics-Puresoft-PU-Padded-Mid-Back-Comp...
# ..                                                 ...
# 800  /Distressed-Leather-Tufted-Coffee-Ottoman/prod...
# 801  /Distressed-Leather-Tufted-Coffee-Ottoman/prod...
# 802  /Distressed-Leather-Tufted-Coffee-Ottoman/prod...
# 803  /Distressed-Leather-Tufted-Coffee-Ottoman/prod...
# 804  /Distressed-Leather-Tufted-Coffee-Ottoman/prod...
#
# [94440 rows x 12 columns]

# %%
# Define functions that I'll use to pre-process the data

# Remove / and replace with a space instead
def remove_dash(text):
    output = ""
    for i in range(len(text)):
        if text[i] == "/":
            output += " "
            continue
        if text[i] == "\\":
            output = " "
            continue
        output += text[i]
    return output

# Punctuation adds no meaning to text, remove it
def remove_punctuation(text):
    no_punct=[words for words in text if words not in string.punctuation]
    words_wo_punct=''.join(no_punct)
    return words_wo_punct

# Split sentences into individual strings
def tokenize(text):
    split=re.split("\W+",text) 
    return split

# Remove stopwords
stopword = nltk.corpus.stopwords.words('english')
def remove_stopwords(text):
    text_out=[word for word in text if word not in stopword]
    return text_out

# Get the root of each of the words (decrease number of distinct words)
def lemmatize_text(words):
    """Lemmatize verbs in list of tokenized words"""
    lemmatizer = WordNetLemmatizer()
    lemmas = []
    for word in words:
        lemma = lemmatizer.lemmatize(word, pos='v')
        lemmas.append(lemma)
    return lemmas

# %%
# %%capture
# We'll make a new dataframe that has only the data we're interested in
cols = ['Type', 'id', 'title', 'content']
reviews = products[cols]

# Remove any rows that don't have review data
reviews.dropna(subset = ["content"], inplace=True)

# Apply the cleaning functions
reviews['review_length'] = reviews['content'].astype(str).apply(len)
reviews['word_count'] = reviews['content'].apply(lambda x: len(str(x).split()))
reviews['no_dashes'] = reviews['content'].apply(lambda x: remove_dash(x))
reviews['lower_case'] = reviews['no_dashes'].apply(lambda x: x.lower())
reviews['no_punctuation'] = reviews['lower_case'].apply(lambda x: remove_punctuation(x))
# reviews['no_stops'] = reviews['no_punctuation'].apply(lambda x: remove_stopwords(x))
reviews['tokenized'] = reviews['no_punctuation'].apply(lambda x: tokenize(x))
reviews['no_stops'] = reviews['tokenized'].apply(lambda x: remove_stopwords(x))
reviews['lemmatized'] = reviews['no_stops'].apply(lambda x: lemmatize_text(x))

# %%
display(reviews)
# Out:
#              Type   id                                      title  \
# 0    office+chair    0  Good if you only need a chair for a month
# 1    office+chair    0                                Unfortunate
# 2    office+chair    0                   Wrong parts and unusable
# 3    office+chair    0             the chair back rest was hollow
# 4    office+chair    0           Great Office Chair for the money
# ..            ...  ...                                        ...
# 800  coffee+table  444                  I am over the moon happy!
# 801  coffee+table  444              Beyond any expectations I had
# 802  coffee+table  444                  Great Ottoman, Good Price
# 803  coffee+table  444           Practically perfect in every way
# 804  coffee+table  444         Cushion is comfy like memory foam!
#
#                                                content  review_length  \
# 0    The fabric/pleather on this chair has torn aft...            405
# 1    Received chair and all of the parts for assemb...            754
# 2                   Came with incorrect mount for seat             34
# 3    the back rest was hollow, when i received the ...            726
# 4    After reading all of the reviews I decided to ...            759
# ..                                                 ...            ...
# 800  There is absolutely everything right about thi...            511
# 801  This is a beautiful piece of furniture. It can...             73
# 802  This ottoman really does the job in my living ...            546
# 803  Gorgeous piece that feels so custom because it...            286
# 804  This is a great item. Easy to assemble- just t...            512
#
#      word_count                                          no_dashes  \
# 0            75  The fabric pleather on this chair has torn aft...
# 1           144  Received chair and all of the parts for assemb...
# 2             6                 Came with incorrect mount for seat
# 3           138  the back rest was hollow, when i received the ...
# 4           145  After reading all of the reviews I decided to ...
# ..          ...                                                ...
# 800          91  There is absolutely everything right about thi...
# 801          14  This is a beautiful piece of furniture. It can...
# 802          98  This ottoman really does the job in my living ...
# 803          52  Gorgeous piece that feels so custom because it...
# 804         104  This is a great item. Easy to assemble- just t...
#
#                                             lower_case  \
# 0    the fabric pleather on this chair has torn aft...
# 1    received chair and all of the parts for assemb...
# 2                   came with incorrect mount for seat
# 3    the back rest was hollow, when i received the ...
# 4    after reading all of the reviews i decided to ...
# ..                                                 ...
# 800  there is absolutely everything right about thi...
# 801  this is a beautiful piece of furniture. it can...
# 802  this ottoman really does the job in my living ...
# 803  gorgeous piece that feels so custom because it...
# 804  this is a great item. easy to assemble- just t...
#
#                                         no_punctuation  \
# 0    the fabric pleather on this chair has torn aft...
# 1    received chair and all of the parts for assemb...
# 2                   came with incorrect mount for seat
# 3    the back rest was hollow when i received the p...
# 4    after reading all of the reviews i decided to ...
# ..                                                 ...
# 800  there is absolutely everything right about thi...
# 801  this is a beautiful piece of furniture it can ...
# 802  this ottoman really does the job in my living ...
# 803  gorgeous piece that feels so custom because it...
# 804  this is a great item easy to assemble just the...
#
#                                              tokenized  \
# 0    [the, fabric, pleather, on, this, chair, has, ...
# 1    [received, chair, and, all, of, the, parts, fo...
# 2            [came, with, incorrect, mount, for, seat]
# 3    [the, back, rest, was, hollow, when, i, receiv...
# 4    [after, reading, all, of, the, reviews, i, dec...
# ..                                                 ...
# 800  [there, is, absolutely, everything, right, abo...
# 801  [this, is, a, beautiful, piece, of, furniture,...
# 802  [this, ottoman, really, does, the, job, in, my...
# 803  [gorgeous, piece, that, feels, so, custom, bec...
# 804  [this, is, a, great, item, easy, to, assemble,...
#
#                                               no_stops  \
# 0    [fabric, pleather, chair, torn, month, daily, ...
# 1    [received, chair, parts, assembly, zippered, b...
# 2                       [came, incorrect, mount, seat]
# 3    [back, rest, hollow, received, product, box, p...
# 4    [reading, reviews, decided, purchase, amazonba...
# ..                                                 ...
# 800  [absolutely, everything, right, ottoman, look,...
# 801  [beautiful, piece, furniture, easily, fit, style]
# 802  [ottoman, really, job, living, room, great, he...
# 803  [gorgeous, piece, feels, custom, imperfect, pe...
# 804  [great, item, easy, assemble, legs, bit, bulky...
#
#                                             lemmatized
# 0    [fabric, pleather, chair, tear, month, daily, ...
# 1    [receive, chair, part, assembly, zipper, back,...
# 2                       [come, incorrect, mount, seat]
# 3    [back, rest, hollow, receive, product, box, pa...
# 4    [read, review, decide, purchase, amazonbasics,...
# ..                                                 ...
# 800  [absolutely, everything, right, ottoman, look,...
# 801  [beautiful, piece, furniture, easily, fit, style]
# 802  [ottoman, really, job, live, room, great, heig...
# 803  [gorgeous, piece, feel, custom, imperfect, per...
# 804  [great, item, easy, assemble, legs, bite, bulk...
#
# [94414 rows x 12 columns]

# %%
# Let's visualize a bit
reviews['review_length'].iplot(kind='hist',
                               bins=100,
                               xTitle='review length',
                               linecolor='black',
                               yTitle='count',
                               title='Review Text Length Distribution')
# Out:
# <div>                            <div id="06eb231c-4d87-4e00-9a10-20991b949764" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("06eb231c-4d87-4e00-9a10-20991b949764")) {                    Plotly.newPlot(                        "06eb231c-4d87-4e00-9a10-20991b949764",                        [{"histfunc": "count", "histnorm": "", "marker": {"color": "rgba(255, 153, 51, 1.0)", "line": {"color": "#000000", "width": 1.3}}, "name": "review_length", "nbinsx": 100, "opacity": 0.8, "orientation": "v", "type": "histogram", "x": [405, 754, 34, 726, 759, 458, 224, 87, 292, 367, 405, 754, 34, 726, 759, 458, 224, 87, 292, 367, 272, 926, 173, 322, 221, 677, 288, 727, 437, 417, 450, 211, 227, 884, 189, 361, 1840, 537, 404, 1303, 267, 816, 677, 591, 400, 386, 355, 878, 946, 159, 613, 475, 206, 1146, 49, 200, 385, 231, 375, 659, 334, 422, 458, 495, 926, 480, 541, 427, 205, 249, 406, 280, 829, 387, 247, 553, 195, 300, 191, 462, 447, 274, 222, 23, 313, 144, 312, 288, 137, 281, 160, 175, 292, 149, 88, 211, 107, 245, 245, 166, 243, 47, 348, 197, 214, 258, 258, 35, 221, 485, 160, 272, 313, 197, 241, 140, 343, 111, 201, 86, 181, 295, 216, 150, 80, 44, 275, 231, 251, 136, 39, 28, 246, 218, 233, 161, 50, 268, 145, 213, 245, 114, 61, 148, 137, 85, 274, 367, 168, 139, 184, 138, 245, 135, 125, 126, 190, 326, 389, 148, 134, 31, 200, 89, 191, 76, 172, 224, 81, 226, 50, 84, 158, 81, 63, 61, 194, 59, 138, 62, 59, 64, 169, 61, 95, 268, 348, 100, 110, 42, 152, 293, 210, 184, 39, 35, 101, 119, 73, 30, 93, 45, 118, 44, 71, 19, 71, 64, 126, 186, 43, 129, 57, 38, 40, 69, 222, 144, 11, 110, 20, 128, 43, 12, 40, 28, 117, 47, 189, 243, 56, 26, 152, 104, 193, 250, 104, 139, 73, 35, 38, 149, 109, 24, 63, 26, 60, 84, 55, 13, 55, 110, 76, 98, 69, 78, 91, 80, 89, 139, 181, 47, 108, 223, 200, 23, 89, 195, 64, 122, 143, 172, 187, 42, 183, 17, 151, 51, 8, 180, 38, 31, 31, 52, 41, 62, 15, 139, 161, 146, 144, 90, 158, 29, 143, 156, 113, 125, 35, 85, 112, 81, 149, 78, 144, 49, 34, 84, 50, 54, 92, 102, 136, 41, 105, 82, 7, 78, 95, 8, 113, 77, 28, 105, 108, 34, 64, 76, 18, 29, 12, 96, 82, 25, 63, 86, 29, 102, 55, 41, 39, 38, 64, 54, 78, 66, 7, 78, 31, 82, 47, 25, 31, 61, 37, 43, 56, 28, 50, 47, 16, 41, 51, 30, 37, 
, 26, 10, 48, 44, 40, 7, 7, 36, 10, 52, 52, 29, 3, 37, 48, 2, 33, 50, 35, 26, 29, 31, 42, 41, 29, 34, 32, 6, 20, 10, 29, 44, 43, 19, 2, 20, 17, 20, 1, 24, 21, 24, 14, 25, 4, 3, 18, 13, 37, 13, 22, 17, 20, 19, 15, 7, 18, 5, 28, 26, 30, 15, 23, 31, 34, 25, 16, 26, 12, 22, 12, 19, 21, 21, 4, 15, 22, 3, 2, 13, 3, 4, 1, 14, 5, 20, 6, 10, 4, 3, 9, 9, 7, 4, 2, 5, 1, 1, 8, 41, 51, 63, 21, 14, 34, 148, 85, 230, 712, 148, 79, 94, 130, 127, 275, 148, 85, 230, 712, 148, 79, 94, 130, 127, 275, 363, 59, 32, 239, 336, 233, 263, 227, 373, 253, 89, 388, 371, 295, 211, 402, 81, 175, 150, 234, 148, 157, 304, 267, 260, 128, 130, 220, 240, 376, 221, 188, 142, 290, 111, 290, 168, 637, 155, 140, 251, 410, 162, 162, 429, 214, 128, 185, 289, 320, 450, 187, 58, 116, 98, 151, 241, 111, 255, 141, 226, 337, 197, 139, 161, 212, 137, 141, 102, 109, 167, 223, 123, 92, 93, 213, 129, 131, 114, 128, 240, 117, 150, 253, 97, 185, 102, 153, 345, 80, 181, 281, 147, 116, 121, 128, 158, 169, 144, 113, 108, 202, 323, 89, 112, 125, 195, 167, 324, 144, 124, 224, 278, 118, 62, 67, 759, 112, 118, 217, 145, 57, 235, 268, 72, 92, 115, 157, 233, 66, 161, 101, 92, 162, 95, 113, 92, 512, 106, 88, 324, 104, 387, 182, 78, 142, 233, 124, 71, 139, 80, 90, 128, 103, 146, 252, 131, 225, 320, 352, 160, 163, 77, 238, 95, 57, 103, 81, 154, 78, 69, 98, 123, 81, 136, 181, ...

# %%
# This is the number of reviews per product
reviews.groupby('id')["content"].count()
# This is the number of total reviews
print(len(reviews["content"]))
# Out:
# 94414

# %%
# Let's make input for the w2v model
sentences = []
for i in range(0, len(reviews['lemmatized'])):
    sentences.append(reviews['lemmatized'].iloc[i])
    
for i in range(0, 5):
    print(sentences[i])
    print("")
    
type(sentences[0])
# Out:
# ['fabric', 'pleather', 'chair', 'tear', 'month', 'daily', 'use', 'super', 'comfortable', 'relatively', 'easy', 'assemble', 'really', 'enjoy', 'time', 'function', 'would', 'like', 'return', 'product', 'ship', 'especially', 'pandemic', 'never', 'write', 'review', 'purchase', 'end', 'bummer', 'give', 'money', 'back', 'without', 'return', 'mr', 'bezos', 'send', 'new', 'chair']
#
# ['receive', 'chair', 'part', 'assembly', 'zipper', 'back', 'unfortunately', 'make', 'little', 'sense', 'unzip', 'back', 'notice', 'one', 'zipper', 'teeth', 'miss', 'subsequently', 'zipper', 'go', 'track', 'come', 'apart', 'continue', 'put', 'chair', 'together', 'figure', 'would', 'try', 'deal', 'zipper', 'later', 'chair', 'simple', 'assemble', 'however', 'take', 'lot', 'finagle', 'get', 'zipper', 'back', 'together', 'still', 'require', 'dab', 'glue', 'keep', 'hold', 'wonder', 'return', 'chair', 'take', 'weeks', 'get', 'first', 'place', 'want', 'wait', 'exchange', 'need', 'office', 'chair', 'really', 'hop', 'better', 'experience']
#
# ['come', 'incorrect', 'mount', 'seat']
#
# ['back', 'rest', 'hollow', 'receive', 'product', 'box', 'part', 'inside', 'back', 'rest', 'zip', 'remove', 'part', 'pad', 'use', 'harbor', 'freight', 'move', 'blanket', 'fold', 'stuff', 'inside', 'back', 'rest', 'make', 'perfect', 'still', 'wtf', 'dont', 'buy', 'desk', 'chair', 'expect', 'back', 'rest', 'thick', 'hollow', 'like', 'really', 'isnt', 'pinata', 'buy', 'spare', 'blanket', 'dont', 'want', 'would', 'like', 'use', 'internal', 'pad', 'chair', 'overall', 'harbor', 'freight', 'blanket', 'stuff', 'really', 'nice', 'chair', 'lol', 'note', 'harbor', 'freight', 'move', 'blanket', 'like', '5', 'fyi', 'decent', 'pad', 'fold', 'make', 'lot', 'pad']
#
# ['read', 'review', 'decide', 'purchase', 'amazonbasics', 'office', 'chair', 'like', 'fact', 'light', 'weight', 'move', 'yet', 'sturdy', 'sit', 'start', 'feel', 'hard', 'hours', 'sit', 'seat', 'height', 'adjustment', 'great', 'work', 'well', 'lower', 'seat', 'put', 'shoe', 'raise', 'sit', 'computer', 'comment', 'vinyl', 'cover', 'look', 'nice', 'feel', 'soft', 'dont', 'know', 'long', 'cover', 'last', 'allinall', 'amazonbasics', 'office', 'chair', 'good', 'value', 'money', 'careful', 'instal', 'seat', 'armrest', 'screw', 'strip', 'thread', 'pull', 'chair', 'stuff', 'miss', 'hole', 'turn', 'screw']
# list

# %%
# Okay, now the data is cleaned up, we can begin with word2vec
model = gensim.models.Word2Vec(sentences, min_count=25, window=5, size=100)
# size      : should be low (~100) if you don't have much data and large (~1000) if you have a lot of data
# window    : is how many words to search for a keyword
# min_count : the model will ignore words which do not appear at least this frequently

# %%
# %%capture
model.wv.vocab

# %%
# Just a few things to show what we can do with w2v
target = 'tool'
compare = 'hammer'
model.wv.most_similar(positive=target)
# model.wv.similarity(w1=target, w2=compare)
# Out:
# [('screwdriver', 0.771315336227417),
#  ('screwdrivers', 0.7157742977142334),
#  ('allen', 0.6908113956451416),
#  ('ratchet', 0.6861602663993835),
#  ('phillips', 0.6662878394126892),
#  ('wrench', 0.6520792245864868),
#  ('driver', 0.6354129314422607),
#  ('hex', 0.6314098834991455),
#  ('philips', 0.6286501288414001),
#  ('alan', 0.6120986342430115)]

# %%
target_word = "assemble"
selected_words = [w[0] for w in model.wv.most_similar(positive=[target_word], topn=100)]
embeddings = [model.wv[w] for w in selected_words]

mapped_embeddings = TSNE(n_components=2, metric='cosine', init='pca').fit_transform(embeddings)

# %%
plt.figure(figsize=(30,30))
x = mapped_embeddings[:,0]
y = mapped_embeddings[:,1]
plt.scatter(x, y)

for i, txt in enumerate(selected_words):
    plt.annotate(txt, (x[i], y[i]), size=25)
